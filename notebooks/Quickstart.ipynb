# %% [markdown]
# Import modules

# %%
# %matplotlib inline
import poppy_inverse_kinematics.creature as model_creature

# %% [markdown]
# Create your model

# %%
left_arm = model_creature.creature("torso_left_arm")

# %% [markdown]
# Set the target

# %%
left_arm.target = [1, 1, 1]

# %% [markdown]
# Go to your target

# %%
left_arm.goto_target()

# %%
left_arm.plot_model()
